# %%
import json
import pandas as pd
import numpy as np

# %%
with open("hamedan_data.json","r") as f :
    c = json.loads(f.readline())

hamedan_df = pd.read_json("hamedan_data.json")
data_rev2 = hamedan_df[::-1].reset_index(drop = True)
hamedan_df.head(20)
# Out:
#                                                                       1   \
# name                                                     فست فود بام سبز
# rate                                                                 2.1
# delivery                              25 تا 50 دقیقه\nمیانگین زمان ارسال
# menu                   [{'name': 'پیتزا برتولی', 'price': '159,000 تو...
# out_of_zone_available                              دارد (ارسال با آژانس)
# time_available                                     دارد (ارسال با آژانس)
# address_by_str                 پیاده راه بوعلی، مرکز خرید شهرآرا- طبقه 4
# address_by_geo                       34.79443995991236,48.51489812135697
#
#                                                                       2   \
# name                                                       تهیه غذای ناب
# rate                                                                 4.6
# delivery                              15 تا 30 دقیقه\nمیانگین زمان ارسال
# ...
